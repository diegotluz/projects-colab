# %% [markdown]
# <a href="https://colab.research.google.com/github/diegotluz/projects-colab/blob/main/pegagio_imigrantes_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df= pd.read_xml("https://dados.tce.rs.gov.br/dados/municipal/balancete-receita/2024/68200.xml")

# %%
df.head()
# Out:
#     ANO  MES  COD_MUNICIPIO NOME_MUNICIPIO  CD_ORGAO       NOME_ORGAO  \
# 0  2024    6            282      IMIGRANTE     68200  PM DE IMIGRANTE
# 1  2024    6            282      IMIGRANTE     68200  PM DE IMIGRANTE
# 2  2024    6            282      IMIGRANTE     68200  PM DE IMIGRANTE
# 3  2024    6            282      IMIGRANTE     68200  PM DE IMIGRANTE
# 4  2024    6            282      IMIGRANTE     68200  PM DE IMIGRANTE
#
#    CD_RECEBIMENTO  CD_ORGAO_ORCAMENTARIO NOME_ORGAO_ORCAMENTARIO  \
# 0          332938                      0                    None
# 1          332938                      0                    None
# 2          332938                      0                    None
# 3          332938                      0                    None
# 4          332938                      0                    None
#
#    CD_UNIDADE_ORCAMENTARIA  ... NIVEL NR_NIVEL CD_RECURSO NM_RECURSO  \
# 0                        0  ...     S        1          0        NaN
# ...

# %%
df.to_csv("68200.csv")
